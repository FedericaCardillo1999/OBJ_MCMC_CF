# %% [markdown]
# # Load the Population Receptive Field properties for the Connective Fields

# %%
import pandas as pd
import numpy as np
import os 
import pickle 
from nibabel.freesurfer.io import read_morph_data, write_morph_data
import io

# %%
MAIN_PATH = '/Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives'
freesurfer = f"{MAIN_PATH}/freesurfer"
source = 'V1'
denoising = 'nordic'
atlases = ['benson', 'manual']
subjects = [f'sub-{i:02}' for i in range(2, 47)]
tasks = ['RET2','RET']
#tasks = ['RestingState']
hemispheres = ['lh', 'rh']
visual_areas = ['V1', 'V2', 'V3']
analysis = 'benson total'  # or 'benson total' or 'standard

# %%
class PRFModel:
    def __init__(self, r2, size, ecc, angle):
        self.r2 = r2        
        self.size = size
        self.ecc = ecc    
        self.angle = angle     

def pickle_file(filepath):
    if not os.path.isfile(filepath):
        raise FileNotFoundError(f"File not found: {filepath}")
    with open(filepath, 'rb') as file: 
        return pickle.load(file)

def load_prf(subj, main_path, atlas, denoising, task):
    filename_task = 'RET' if task == 'RestingState' else task
    filepath = os.path.join(
        main_path,
        f'pRFM/{subj}/ses-02/{denoising}/model-{atlas}-nelder-mead-GM_desc-prf_params_{filename_task}.pkl')
    pkl_data = pickle_file(filepath)
    prf_params = pkl_data['model'].iterative_search_params     
    prf_voxels = np.where(pkl_data['rois_mask'] == 1)[0]
    return prf_params, prf_voxels

def filter_prf(prf_params, prf_voxels):
    return PRFModel(
        r2=prf_params[:, 7],
        size=prf_params[:, 2],
        ecc=np.sqrt(prf_params[:, 1]**2 + prf_params[:, 0]**2),
        angle=np.arctan2(prf_params[:, 1], prf_params[:, 0]))

def load_label_data(label_path):
    with open(label_path, 'r') as f:
        lines = f.readlines()
    lines = lines[2:]  # skip header
    data = [line.strip().split() for line in lines]
    indices = [int(row[0]) for row in data]
    values = [float(row[4]) for row in data]  # value stored in 5th column
    return dict(zip(indices, values))

def extract_prf_previous(subj, hemi, target, csv_path, prf_params, prf_voxels):
    best_fit = pd.read_csv(csv_path)

    if 'Target Vertex Index' in best_fit.columns:
        repeated_header_rows = best_fit['Target Vertex Index'] == 'Target Vertex Index'
        if repeated_header_rows.any():
            best_fit = best_fit[~repeated_header_rows]

    best_fit['Source Vertex Index'] = best_fit['Source Vertex Index'].astype(int)
    best_fit['Target Vertex Index'] = best_fit['Target Vertex Index'].astype(int)

    prf_model = filter_prf(prf_params, prf_voxels)
    lh_c = read_morph_data(f'{freesurfer}/{subj}/surf/lh.curv')
    numel_lh = lh_c.shape[0]

    if hemi == 'rh':
        prf_voxels_rh = prf_voxels[prf_voxels >= numel_lh]
        prf_voxels_rh_adjusted = prf_voxels_rh - numel_lh
        prf_ecc_rh = prf_model.ecc[prf_voxels >= numel_lh]
        prf_angle_rh = prf_model.angle[prf_voxels >= numel_lh]
        voxel_to_ecc = dict(zip(prf_voxels_rh_adjusted, prf_ecc_rh))
        voxel_to_angle = dict(zip(prf_voxels_rh_adjusted, prf_angle_rh))
    else:
        voxel_to_ecc = dict(zip(prf_voxels, prf_model.ecc))
        voxel_to_angle = dict(zip(prf_voxels, prf_model.angle))

    best_fit['Source Eccentricity'] = best_fit['Source Vertex Index'].map(voxel_to_ecc)
    best_fit['Source Polar Angle'] = best_fit['Source Vertex Index'].map(voxel_to_angle)
    return best_fit

def extract_prf(subj, hemi, target, csv_path, prf_params, prf_voxels):
    best_fit = pd.read_csv(csv_path)

    if 'Target Vertex Index' in best_fit.columns:
        repeated_header_rows = best_fit['Target Vertex Index'] == 'Target Vertex Index'
        if repeated_header_rows.any():
            best_fit = best_fit[~repeated_header_rows]

    best_fit['Source Vertex Index'] = best_fit['Source Vertex Index'].astype(int)
    best_fit['Target Vertex Index'] = best_fit['Target Vertex Index'].astype(int)

    if analysis == 'benson total':
        label_dir = os.path.join(freesurfer, subj, 'label')
        ecc_path = os.path.join(label_dir, f'{hemi}.benson14_eccen-0001.label')
        ang_path = os.path.join(label_dir, f'{hemi}.benson14_angle-0001.label')

        ecc_map = load_label_data(ecc_path)
        ang_map = load_label_data(ang_path)

        best_fit['Source Eccentricity'] = best_fit['Source Vertex Index'].map(ecc_map)
        best_fit['Source Polar Angle'] = best_fit['Source Vertex Index'].map(ang_map)

    else:
        prf_model = filter_prf(prf_params, prf_voxels)
        lh_c = read_morph_data(f'{freesurfer}/{subj}/surf/lh.curv')
        numel_lh = lh_c.shape[0]

        if hemi == 'rh':
            prf_voxels_rh = prf_voxels[prf_voxels >= numel_lh]
            prf_voxels_rh_adjusted = prf_voxels_rh - numel_lh
            prf_ecc_rh = prf_model.ecc[prf_voxels >= numel_lh]
            prf_angle_rh = prf_model.angle[prf_voxels >= numel_lh]
            voxel_to_ecc = dict(zip(prf_voxels_rh_adjusted, prf_ecc_rh))
            voxel_to_angle = dict(zip(prf_voxels_rh_adjusted, prf_angle_rh))
        else:
            voxel_to_ecc = dict(zip(prf_voxels, prf_model.ecc))
            voxel_to_angle = dict(zip(prf_voxels, prf_model.angle))

        best_fit['Source Eccentricity'] = best_fit['Source Vertex Index'].map(voxel_to_ecc)
        best_fit['Source Polar Angle'] = best_fit['Source Vertex Index'].map(voxel_to_angle)

    return best_fit

def header_fix(path, expected_column='Target Vertex Index'):
    with open(path, 'r') as f:
        lines = f.readlines()
    for idx, line in enumerate(lines):
        if expected_column in line:
            header = line
            data = lines[idx + 1:]
            break
    csv_content = ''.join([header] + data)
    return pd.read_csv(io.StringIO(csv_content))

# %%
for subj in subjects:
    for atlas in atlases:
        for task in tasks:
            runs = ['']
            if task == 'RestingState':
                runs = ['run-1', 'run-2']

            for run in runs:
                try:
                    prf_params, prf_voxels = load_prf(subj, MAIN_PATH, atlas, denoising, task)
                except Exception as e:
                    print(f"Missing pRF pkl file - Subject: {subj}, Atlas: {atlas}, Task: {task}, Run: {run}: {e}")
                    continue

                for hemi in hemispheres:
                    for target in visual_areas[1:]:  
                        source_target = f"{target}-V1"

                        if task == 'RestingState':
                            best_fit_path = f"{MAIN_PATH}/CFM/{subj}/ses-02/{atlas}/{task}/{run}/{denoising}/GM/{hemi}/{source_target}/best_fits.csv"
                        else:
                            best_fit_path = f"{MAIN_PATH}/CFM/{subj}/ses-02/{atlas}/{task}/{denoising}/GM/{hemi}/{source_target}/best_fits.csv"

                        if not os.path.exists(best_fit_path):
                            print(f'Missing best_fits.csv for {subj}, {atlas}, {target}, {task}, {run}, {hemi}')
                            continue

                        try:
                            best_fit_prf = extract_prf(subj, hemi, target, best_fit_path, prf_params, prf_voxels)
                        except Exception as e:
                            if isinstance(e, KeyError) and 'Source Vertex Index' in str(e):
                                best_fit = header_fix(best_fit_path)
                                best_fit.to_csv(best_fit_path, index=False) 
                                best_fit_prf = extract_prf(subj, hemi, target, best_fit_path, prf_params, prf_voxels)
                            else:
                                print(f'Error processing {subj}, {atlas}, {task}, {run}, {hemi}, {target}: {e}')
                                continue

                        # Save to individual_fits directory
                        output_dir = os.path.join(os.path.dirname(best_fit_path))
                        os.makedirs(output_dir, exist_ok=True)
                        output_path = os.path.join(output_dir, 'best_fits_prf.csv')
                        best_fit_prf.to_csv(output_path, index=False)

                        best_fit_prf.to_csv(output_path, index=False)
                        print(f"[SAVED] best_fits_prf.csv for {subj} | {atlas} | {task} | {run} | {hemi} | {target} here: {output_path}")

                        target_idx = best_fit_prf['Target Vertex Index'].astype(int).values
                        curv = read_morph_data(f'{freesurfer}/{subj}/surf/{hemi}.curv')

                        def write_data_to_surface(values, suffix):
                            masked = np.full(curv.shape[0], 50.0)
                            masked[target_idx] = values
                            output_file = f'{freesurfer}/{subj}/surf/{hemi}.{suffix}_{target}{source}_{denoising}_{task}{("_" + run) if run else ""}_{atlas}'
                            write_morph_data(output_file, masked)

                        write_data_to_surface(best_fit_prf['Source Eccentricity'].values, 'ecc')
                        write_data_to_surface(best_fit_prf['Source Polar Angle'].values, 'pol')
                        write_data_to_surface(best_fit_prf['Best Variance Explained Finer'].values, 've')
                        write_data_to_surface(best_fit_prf['Best Sigma Finer'].values, 'sigma')
# Out:
# [SAVED] best_fits_prf.csv for sub-02 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-02 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-02/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# Missing pRF pkl file - Subject: sub-03, Atlas: benson, Task: RET2, Run: : File not found: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/pRFM/sub-03/ses-02/nordic/model-benson-nelder-mead-GM_desc-prf_params_RET2.pkl
# Missing pRF pkl file - Subject: sub-03, Atlas: benson, Task: RET, Run: : File not found: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/pRFM/sub-03/ses-02/nordic/model-benson-nelder-mead-GM_desc-prf_params_RET.pkl
# Missing pRF pkl file - Subject: sub-03, Atlas: manual, Task: RET2, Run: : File not found: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/pRFM/sub-03/ses-02/nordic/model-manual-nelder-mead-GM_desc-prf_params_RET2.pkl
# Missing pRF pkl file - Subject: sub-03, Atlas: manual, Task: RET, Run: : File not found: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/pRFM/sub-03/ses-02/nordic/model-manual-nelder-mead-GM_desc-prf_params_RET.pkl
# [SAVED] best_fits_prf.csv for sub-04 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-04 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-04/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-05 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-05/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# Missing pRF pkl file - Subject: sub-06, Atlas: benson, Task: RET2, Run: : File not found: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/pRFM/sub-06/ses-02/nordic/model-benson-nelder-mead-GM_desc-prf_params_RET2.pkl
# Missing best_fits.csv for sub-06, benson, V2, RET, , lh
# Missing best_fits.csv for sub-06, benson, V3, RET, , lh
# Missing best_fits.csv for sub-06, benson, V2, RET, , rh
# Missing best_fits.csv for sub-06, benson, V3, RET, , rh
# Missing pRF pkl file - Subject: sub-06, Atlas: manual, Task: RET2, Run: : File not found: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/pRFM/sub-06/ses-02/nordic/model-manual-nelder-mead-GM_desc-prf_params_RET2.pkl
# [SAVED] best_fits_prf.csv for sub-06 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-06/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-06 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-06/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-06 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-06/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-06 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-06/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-07 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-07/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-08 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-08/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-09 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-09/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-10 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-10/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# Missing best_fits.csv for sub-11, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-11, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-11, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-11, benson, V3, RET2, , rh
# [SAVED] best_fits_prf.csv for sub-11 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-11 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-11/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-12 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-12/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# Missing pRF pkl file - Subject: sub-13, Atlas: benson, Task: RET2, Run: : File not found: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/pRFM/sub-13/ses-02/nordic/model-benson-nelder-mead-GM_desc-prf_params_RET2.pkl
# Missing best_fits.csv for sub-13, benson, V2, RET, , lh
# Missing best_fits.csv for sub-13, benson, V3, RET, , lh
# Missing best_fits.csv for sub-13, benson, V2, RET, , rh
# Missing best_fits.csv for sub-13, benson, V3, RET, , rh
# Missing pRF pkl file - Subject: sub-13, Atlas: manual, Task: RET2, Run: : File not found: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/pRFM/sub-13/ses-02/nordic/model-manual-nelder-mead-GM_desc-prf_params_RET2.pkl
# [SAVED] best_fits_prf.csv for sub-13 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-13/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-13 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-13/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-13 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-13/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-13 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-13/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-14 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-14/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-15 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-15/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-16 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-16/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | benson | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/benson/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | benson | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/benson/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | benson | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/benson/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | benson | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/benson/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | benson | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/benson/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | benson | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/benson/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-17 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-17/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# ...
# [SAVED] best_fits_prf.csv for sub-34 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-34/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-34 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-34/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-34 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-34/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-34 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-34/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-34 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-34/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-34 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-34/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-34 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-34/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-34 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-34/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# Missing best_fits.csv for sub-35, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-35, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-35, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-35, benson, V3, RET2, , rh
# [SAVED] best_fits_prf.csv for sub-35 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-35 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# Missing best_fits.csv for sub-35, benson, V2, RET, , rh
# Missing best_fits.csv for sub-35, benson, V3, RET, , rh
# [SAVED] best_fits_prf.csv for sub-35 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-35 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-35 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-35 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-35 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-35 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-35 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-35 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-35/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# Missing best_fits.csv for sub-36, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-36, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-36, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-36, benson, V3, RET2, , rh
# [SAVED] best_fits_prf.csv for sub-36 | benson | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/benson/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-36 | benson | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/benson/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# Missing best_fits.csv for sub-36, benson, V2, RET, , rh
# Missing best_fits.csv for sub-36, benson, V3, RET, , rh
# [SAVED] best_fits_prf.csv for sub-36 | manual | RET2 |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/manual/RET2/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-36 | manual | RET2 |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/manual/RET2/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-36 | manual | RET2 |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/manual/RET2/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-36 | manual | RET2 |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/manual/RET2/nordic/GM/rh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-36 | manual | RET |  | lh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/manual/RET/nordic/GM/lh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-36 | manual | RET |  | lh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/manual/RET/nordic/GM/lh/V3-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-36 | manual | RET |  | rh | V2 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/manual/RET/nordic/GM/rh/V2-V1/best_fits_prf.csv
# [SAVED] best_fits_prf.csv for sub-36 | manual | RET |  | rh | V3 here: /Volumes/FedericaCardillo/pre-processing/projects/PROJECT_EGRET-AAA/derivatives/CFM/sub-36/ses-02/manual/RET/nordic/GM/rh/V3-V1/best_fits_prf.csv
# Missing best_fits.csv for sub-37, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-37, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-37, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-37, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-37, benson, V2, RET, , lh
# Missing best_fits.csv for sub-37, benson, V3, RET, , lh
# Missing best_fits.csv for sub-37, benson, V2, RET, , rh
# Missing best_fits.csv for sub-37, benson, V3, RET, , rh
# Missing best_fits.csv for sub-37, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-37, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-37, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-37, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-37, manual, V2, RET, , lh
# Missing best_fits.csv for sub-37, manual, V3, RET, , lh
# Missing best_fits.csv for sub-37, manual, V2, RET, , rh
# Missing best_fits.csv for sub-37, manual, V3, RET, , rh
# Missing best_fits.csv for sub-38, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-38, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-38, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-38, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-38, benson, V2, RET, , lh
# Missing best_fits.csv for sub-38, benson, V3, RET, , lh
# Missing best_fits.csv for sub-38, benson, V2, RET, , rh
# Missing best_fits.csv for sub-38, benson, V3, RET, , rh
# Missing best_fits.csv for sub-38, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-38, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-38, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-38, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-38, manual, V2, RET, , lh
# Missing best_fits.csv for sub-38, manual, V3, RET, , lh
# Missing best_fits.csv for sub-38, manual, V2, RET, , rh
# Missing best_fits.csv for sub-38, manual, V3, RET, , rh
# Missing best_fits.csv for sub-39, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-39, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-39, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-39, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-39, benson, V2, RET, , lh
# Missing best_fits.csv for sub-39, benson, V3, RET, , lh
# Missing best_fits.csv for sub-39, benson, V2, RET, , rh
# Missing best_fits.csv for sub-39, benson, V3, RET, , rh
# Missing best_fits.csv for sub-39, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-39, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-39, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-39, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-39, manual, V2, RET, , lh
# Missing best_fits.csv for sub-39, manual, V3, RET, , lh
# Missing best_fits.csv for sub-39, manual, V2, RET, , rh
# Missing best_fits.csv for sub-39, manual, V3, RET, , rh
# Missing best_fits.csv for sub-40, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-40, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-40, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-40, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-40, benson, V2, RET, , lh
# Missing best_fits.csv for sub-40, benson, V3, RET, , lh
# Missing best_fits.csv for sub-40, benson, V2, RET, , rh
# Missing best_fits.csv for sub-40, benson, V3, RET, , rh
# Missing best_fits.csv for sub-40, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-40, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-40, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-40, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-40, manual, V2, RET, , lh
# Missing best_fits.csv for sub-40, manual, V3, RET, , lh
# Missing best_fits.csv for sub-40, manual, V2, RET, , rh
# Missing best_fits.csv for sub-40, manual, V3, RET, , rh
# Missing best_fits.csv for sub-41, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-41, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-41, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-41, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-41, benson, V2, RET, , lh
# Missing best_fits.csv for sub-41, benson, V3, RET, , lh
# Missing best_fits.csv for sub-41, benson, V2, RET, , rh
# Missing best_fits.csv for sub-41, benson, V3, RET, , rh
# Missing best_fits.csv for sub-41, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-41, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-41, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-41, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-41, manual, V2, RET, , lh
# Missing best_fits.csv for sub-41, manual, V3, RET, , lh
# Missing best_fits.csv for sub-41, manual, V2, RET, , rh
# Missing best_fits.csv for sub-41, manual, V3, RET, , rh
# Missing best_fits.csv for sub-42, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-42, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-42, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-42, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-42, benson, V2, RET, , lh
# Missing best_fits.csv for sub-42, benson, V3, RET, , lh
# Missing best_fits.csv for sub-42, benson, V2, RET, , rh
# Missing best_fits.csv for sub-42, benson, V3, RET, , rh
# Missing best_fits.csv for sub-42, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-42, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-42, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-42, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-42, manual, V2, RET, , lh
# Missing best_fits.csv for sub-42, manual, V3, RET, , lh
# Missing best_fits.csv for sub-42, manual, V2, RET, , rh
# Missing best_fits.csv for sub-42, manual, V3, RET, , rh
# Missing best_fits.csv for sub-43, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-43, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-43, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-43, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-43, benson, V2, RET, , lh
# Missing best_fits.csv for sub-43, benson, V3, RET, , lh
# Missing best_fits.csv for sub-43, benson, V2, RET, , rh
# Missing best_fits.csv for sub-43, benson, V3, RET, , rh
# Missing best_fits.csv for sub-43, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-43, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-43, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-43, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-43, manual, V2, RET, , lh
# Missing best_fits.csv for sub-43, manual, V3, RET, , lh
# Missing best_fits.csv for sub-43, manual, V2, RET, , rh
# Missing best_fits.csv for sub-43, manual, V3, RET, , rh
# Missing best_fits.csv for sub-44, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-44, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-44, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-44, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-44, benson, V2, RET, , lh
# Missing best_fits.csv for sub-44, benson, V3, RET, , lh
# Missing best_fits.csv for sub-44, benson, V2, RET, , rh
# Missing best_fits.csv for sub-44, benson, V3, RET, , rh
# Missing best_fits.csv for sub-44, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-44, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-44, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-44, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-44, manual, V2, RET, , lh
# Missing best_fits.csv for sub-44, manual, V3, RET, , lh
# Missing best_fits.csv for sub-44, manual, V2, RET, , rh
# Missing best_fits.csv for sub-44, manual, V3, RET, , rh
# Missing best_fits.csv for sub-45, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-45, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-45, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-45, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-45, benson, V2, RET, , lh
# Missing best_fits.csv for sub-45, benson, V3, RET, , lh
# Missing best_fits.csv for sub-45, benson, V2, RET, , rh
# Missing best_fits.csv for sub-45, benson, V3, RET, , rh
# Missing best_fits.csv for sub-45, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-45, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-45, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-45, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-45, manual, V2, RET, , lh
# Missing best_fits.csv for sub-45, manual, V3, RET, , lh
# Missing best_fits.csv for sub-45, manual, V2, RET, , rh
# Missing best_fits.csv for sub-45, manual, V3, RET, , rh
# Missing best_fits.csv for sub-46, benson, V2, RET2, , lh
# Missing best_fits.csv for sub-46, benson, V3, RET2, , lh
# Missing best_fits.csv for sub-46, benson, V2, RET2, , rh
# Missing best_fits.csv for sub-46, benson, V3, RET2, , rh
# Missing best_fits.csv for sub-46, benson, V2, RET, , lh
# Missing best_fits.csv for sub-46, benson, V3, RET, , lh
# Missing best_fits.csv for sub-46, benson, V2, RET, , rh
# Missing best_fits.csv for sub-46, benson, V3, RET, , rh
# Missing best_fits.csv for sub-46, manual, V2, RET2, , lh
# Missing best_fits.csv for sub-46, manual, V3, RET2, , lh
# Missing best_fits.csv for sub-46, manual, V2, RET2, , rh
# Missing best_fits.csv for sub-46, manual, V3, RET2, , rh
# Missing best_fits.csv for sub-46, manual, V2, RET, , lh
# Missing best_fits.csv for sub-46, manual, V3, RET, , lh
# Missing best_fits.csv for sub-46, manual, V2, RET, , rh
# Missing best_fits.csv for sub-46, manual, V3, RET, , rh
